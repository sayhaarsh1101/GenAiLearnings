# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv("OPENAI_API_KEY")
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# output_version=None profile={'name': 'GPT-4o', 'release_date': '2024-05-13', 'last_updated': '2024-08-06', 'open_weights': False, 'max_input_tokens': 128000, 'max_output_tokens': 16384, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'pdf_inputs': True, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x113fefa10> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x114350590> root_client=<openai.OpenAI object at 0x113828440> root_async_client=<openai.AsyncOpenAI object at 0x1143502f0> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') openai_proxy=None stream_usage=True stream_chunk_timeout=120.0

# %%
result=llm.invoke("What is generative AI?")

# %%
print(result)
# Out:
# content='Generative AI refers to a category of artificial intelligence systems designed to generate new content or data that resembles the input data they were trained on. This content can include text, images, music, videos, or other types of media. The generative aspect means that these AI models can produce novel outputs rather than just analyzing or acting on existing data. Generative AI is typically powered by machine learning techniques, particularly neural networks, and employs models such as GANs (Generative Adversarial Networks), VAEs (Variational Autoencoders), and transformer-based models (e.g., GPT for text, DALL-E for images).\n\nThese systems are used in a wide variety of applications, ranging from creative fields like art and music to more practical uses such as creating synthetic data for training other AI models, improving natural language processing, or designing new products. Generative AI can automate and augment human creativity by providing new ideas, optimizing designs, or producing human-like interactions in virtual settings. However, it also raises ethical and social implications regarding originality, ownership, and the potential for misuse.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 216, 'prompt_tokens': 13, 'total_tokens': 229, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_5acb5510d6', 'id': 'chatcmpl-DeiaKTL4vbKltV9Inq0HvNoURPWiC', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e1ca2-8e08-7c73-b2dd-9e717718d627-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 216, 'total_tokens': 229, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
### Chatprompt Template
from langchain_core.prompts import ChatPromptTemplate
prompt=ChatPromptTemplate.from_messages(
    [
        ("system","You are an expert AI Engineer. Provide me answers based on the questions"),
        ("user","{input}")
    ]

)
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the questions'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
## chain 
chain=prompt|llm

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# content='Langsmith is a tool designed to aid developers in building, implementing, and optimizing applications powered by large language models (LLMs). It provides a suite of features that allows users to evaluate, monitor, and fine-tune LLM-driven applications. With Langsmith, developers can manage and track their LLMs to ensure they perform effectively and efficiently within their applications. The platform is particularly useful for debugging, testing, and iterating on application prototypes. Integrated with Langchain, Langsmith enhances the workflow for developers using LLMs by enabling better governance and insights into model operations.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 116, 'prompt_tokens': 33, 'total_tokens': 149, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_d74b181336', 'id': 'chatcmpl-DeiaTc6f6pyj9rYJkBDTDTNJeAddQ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e1ca2-b4b3-7503-8ac1-835cec5f0c88-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 33, 'output_tokens': 116, 'total_tokens': 149, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## stroutput Parser

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print(response)
# Out:
# Langsmith is a platform developed by Langchain aimed at helping developers build and optimize applications that leverage language models. The platform offers tools for debugging, testing, monitoring, and evaluating applications to ensure they run efficiently and effectively. It provides features that help identify where an application might be underperforming or encountering issues, allowing developers to make precise improvements. Additionally, Langsmith offers integrations with various language models, facilitating a streamlined workflow for developers who are working with natural language processing applications.

# %%
type(response)
# Out:
# langchain_core.messages.base.TextAccessor
